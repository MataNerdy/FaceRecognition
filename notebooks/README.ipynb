# %% [markdown]
# #Face Recognition

# %% [markdown]
# **Где все:**

# %% [markdown]
# Тут: https://drive.google.com/drive/folders/1v2SegH94J8fOJiLWx54ewRo9jHfT5l8K?usp=sharing

# %% [markdown]
# **А что тут:**

# %% [markdown]
# Пять ноутбуков (не считая этого):
# - 1_StackedHourGlassNetwork_Clean.
# https://drive.google.com/file/d/1YuXbFPEttnFQqW4YekZVKCO5EbmVTDzG/view?usp=sharing
# - 2_AllModels_Clean.ipynb.
# https://drive.google.com/file/d/15HYg8zB1wXvbYmohnJ8aF0N3SvJXkX7i/view?usp=sharing
# - 3_FaceRecognitionPipeline_Clean.ipynb
# https://drive.google.com/file/d/1HSqlw5r9-s0gzGKBuW2-Ac4-fOgefKn-/view?usp=sharing
# - 4_Identification_Rate_Metric_Clean.ipynb
# https://drive.google.com/file/d/1oBhj3N2ZuxOIOz9cQUVjKQdQI6e-nNbz/view?usp=sharing
# - 5_BiblioTest_Clean.ipynb
# https://drive.google.com/file/d/1QQWrMrbItXMTcupOp9s8L6u5KPt38fQ7/view?usp=sharing
#
# В первом все, что касается StackedHourglass.
#
# Во втором все, что касается обучения моделей на всех лоссах:
# - CE
# - ArcFace
# - Triplet
# - Гибриды (включая ArcFace+Triplet).
#
# Для каждой модели достигнуто Val Accuracy > 0.7.
#
# В третьем приведен полный pipeline задачи с примером на четырех фото. Это img1, img2, img3, img4 в папке.
#
# В четвертом реализован Identification Rate Metric и произведена оценка всех моделей из второго ноутбука.
#
# В пятом протестированы три библиотеки, решающих задачу Face Recognition.
#
# Также в папке есть все веса моделей:
# - shg_amazing.pth
# - resnet_ce_best.pth
# - resnet_arcface_best.pth
# - resnet_triplet_best.pth
# - resnet_ce_arcface_best.pth
# - resnet_arcface2_triplet1.pth
#
# Созданные в процессе работы датасеты:
# - aligned_classifier_train_500.zip
# - aligned_classifier_val_500.zip
# - aligned_eval_query.pth
# - aligned_eval_distractors.zip
#
# Фото для тестирования моделей:
#
# - img1.jpg
# - img2.jpg
# - img3.jpg
# - img4.jpg
#
# И CelebA.

# %% [markdown]
# **Что сделано:**

# %% [markdown]
# Почти все

# %% [markdown]
# **Обязательные задания:**
#
#  - ✅  Реализовать и обучить Stacked Hourglass Network для поиска ключевых точек лица, а также написать код, который принимает на вход фотографию лица и возвращает выровненное лицо на основе найденных точек (т.е. реализовать вторую часть пайплайна face recognition);  https://drive.google.com/file/d/1YuXbFPEttnFQqW4YekZVKCO5EbmVTDzG/view?usp=sharing
#
# - ✅  Обучить нейросеть для 3 части пайплайна (распознавание лиц) на CE loss. Для этого можно использовать нейросети, предобученные на ImageNet. Далее нужно реализовать ArcFace Loss и обучить такую же модель на нем. Нельзя брать нейросети, которые уже предобучены на распознавание лиц! В обоих случаях добиться достаточного качества классификации;
# https://drive.google.com/file/d/15HYg8zB1wXvbYmohnJ8aF0N3SvJXkX7i/view?usp=sharing
#
# - ✅  Собрать весь пайплайн распознавания лиц. На вход этому пайплайну должна подаваться картинка с лицами, а на выходе должны быть эмбеддинги всех найденных лиц. Используйте любой предобученный на лицах детектор для первого этапа, а для второго и третьего возьмите ваши модели из заданий 1 и 2. Хорошо будет продемонстрировать работу вашего пайплайна на паре лиц одинаковых и разных людей с подсчетом метрики расстояния между их эмбеддингами.
# https://drive.google.com/file/d/1HSqlw5r9-s0gzGKBuW2-Ac4-fOgefKn-/view?usp=sharing
#
# **Дополнительные задания:**
#
# - ✅ Реализовать Identification Rate Metric. ноутбук к заданию;
# https://drive.google.com/file/d/1oBhj3N2ZuxOIOz9cQUVjKQdQI6e-nNbz/view?usp=sharing
#
# - ✅ Реализовать Triplet loss (предпочтительно) или любой другой актуальный для задачи Face Recognition loss, обучить сеть на нем. Добиться достаточного качества классификации ноутбук к заданию;
# https://drive.google.com/file/d/15HYg8zB1wXvbYmohnJ8aF0N3SvJXkX7i/view?usp=sharing
#
# - ✅ Обучить сеть на смеси ArcFace и лосса из задачи. Добиться достаточного качества классификации;
# https://drive.google.com/file/d/15HYg8zB1wXvbYmohnJ8aF0N3SvJXkX7i/view?usp=sharing
#
# - 🤏  Провести ресерч по open-source решениям для задачи Face Recognition. Отобрать 3 актуальные библиотеки. Сделать текстовое описание каждой из них: написать про возможности и преимущества, сложность установки, требования к вычислительным ресурсам и всё прочее интересное, в том числе и, возможно, ваше мнение. Для каждой библиотеки нужно привести примеры кода для запуска этого решения, протестировав на своих изображениях.
# https://drive.google.com/file/d/1QQWrMrbItXMTcupOp9s8L6u5KPt38fQ7/view?usp=sharing

# %% [markdown]
# Заранее благодарю за ознакомление и любой фидбэк 🙏

# %% [markdown]
# В телеграме я @Nerdniwe. А это картинки из моей работы:

# %% [markdown]
# ![Pipeline landmarks](../assets/readme/pipeline_landmarks.png)

# %% [markdown]
# ![Alignment examples](../assets/readme/alignment_examples.png)

# %% [markdown]
# ![Training curves](../assets/readme/training_curves.png)

# %% [markdown]
# ![Identification Rate](../assets/readme/identification_rate.png)

# %% [markdown]
# ![Retrieval examples](../assets/readme/retrieval_examples.png)
